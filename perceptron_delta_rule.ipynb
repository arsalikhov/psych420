# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot
from pandas import DataFrame
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=3)
# scatter plot, dots colored by class value
ins = []
for i in range(len(X)):
    if y[i] == 0:
        y[i] = -1.0
    ins.append([np.array([X[:,0][i], X[:,1][i], 1]), y[i]])
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {-1:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
w = np.array([3.2,-0.25,0.96])

# %%
def updPercep (i,wt,T=0, nu = 0.1):
    ipt = i[0]
    cls = i[1]
    y = 1 if (ipt @ wt) >= T else -1
    return (wt + (ipt * nu *(cls - y)))

# %%
neww = np.array([w])
for patt in ins:
    tempw = updPercep(patt,neww[-1])
    neww = np.append(neww,np.array([updPercep(patt,neww[-1])]),axis=0)

# %%
wtest = neww[-1]
correct = 0
for i in ins:
    if np.sign(i[0] @ wtest) == i[1]:
        correct+=1
    print(np.sign(i[0] @ wtest) == i[1]) 

print(correct/1000)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
w = np.matrix([[0, -3, 3, -3], [-3, 0, -3, 3], [3, -3, 0, -3], [-3, 3, -3, 0]])

# %%
w
# Out:
# matrix([[ 0, -3,  3, -3],
#         [-3,  0, -3,  3],
#         [ 3, -3,  0, -3],
#         [-3,  3, -3,  0]])

# %%
a = np.array([1, 0, 1, 0]).T
b = np.array([0, 1, 0, 1]).T
c = np.array([1, 0, 0, 0]).T

# %%
w@c
# Out:
# matrix([[ 0, -3,  3, -3]])
